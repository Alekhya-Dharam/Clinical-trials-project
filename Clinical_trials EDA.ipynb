# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ed=pd.read_csv("clinical_trials_Dataset.csv")

# %%
sns.countplot(x=ed['industry_collaborator'])
# Out:
# <Axes: xlabel='industry_collaborator', ylabel='count'>

# %%
sns.countplot(x=ed['industry_sponsor'])
# Out:
# <Axes: xlabel='industry_sponsor', ylabel='count'>

# %%
sns.countplot(x=ed['fda_reg'])
# Out:
# <Axes: xlabel='fda_reg', ylabel='count'>

# %%
sns.countplot(x=ed['placebo_group'])
# Out:
# <Axes: xlabel='placebo_group', ylabel='count'>
